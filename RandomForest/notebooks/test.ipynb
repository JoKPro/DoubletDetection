# %%
import datatable as dt
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# ...

# %%
file = dt.fread("../data/raw/Doubletannotation.csv")

# %%
file2 = dt.fread("../data/raw/pbmc_expr.csv", verbose=True)
# Out:
# [*] Process input parameters
#   Using default 8 thread(s)
#   na_strings = ["NA"]
#   strip_whitespace = True
#   skip_blank_lines = False
#   Input is assumed to be a file name.
# File "../data/raw/pbmc_expr.csv" opened, size: 880299317
# [1] Prepare for reading
#   ==== file sample ====
#   "","AAACAGCCAAAGCCTC.1","AAACAGCCAGAATGAC.1","AAACAGCCAGCTACGT.1","AAACAGCCAGGCCTTG.1","AAACAGCCA...
#   ...GGAC.1","AAACAGCCATAATGTC.1","AAACATGCAGCAATAA.1","AAACATGCAGCCAGAA.1","AAACATGCAGGCGATA.1","A...
#   ...CAGTTTCTC.1","AAACCAACAACTAGGG.1","AAACCAACAATAACCT.1","AAACCAACACTTAGGC.1","AAACCAACAGGACCTT....
#   ...ACCAACAGTTGCGT.1","AAACCAACATCTAGCA.1","AAACCAACATTGTCCT.1","AAACCAACATTTAAGC.1","AAACCGAAGCGA...
#   ...","AAACCGAAGCGTGCGT.1","AAACCGAAGGCCAATT.1","AAACCGCGTAATTAGC.1","AAACCGCGTCGTTACT.1","AAACCGC...
# ...
# Found no \r or \n characters within the first 65536 bytes of input; default \n newlines will be assumed
# [2] Detect parse settings
# ...
